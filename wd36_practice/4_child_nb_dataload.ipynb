# %% [markdown]
# **This is to load the data to the volumn from a source by calling the api**

# %%
import requests

apiResponse = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")
# print(apiResponse.status_code )
volume = "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

dbutils.fs.put(volume,apiResponse.text,overwrite=True)

# %% [markdown]
# **DataLoad Completed**

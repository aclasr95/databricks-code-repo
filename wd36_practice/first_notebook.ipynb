# %%
# %sh ls

# %%
# %fs ls

# %% [markdown]
# ### Mainly three components related to mark down
# ###### 1: Magic Commands
# ###### 2: Widgets
# ###### 3: Utilities

# %% [markdown]
# ### Widgets
# We can make the notebook dynamically by passing as a parameter

# %%
dbutils.widgets.text("batch_name", "Enter the batch name")

# %% [markdown]
# Displaying the util result

# %%
name_of_the_batch = dbutils.widgets.get("batch_name")
print(name_of_the_batch)

# %% [markdown]
# To call one notebook from another notebook using the magic command **%run**
# ###### %run "path/othernotebook" ######

# %% [markdown]
# ### SQL Command
#
# #### Creating a volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.VolumeForWD36
